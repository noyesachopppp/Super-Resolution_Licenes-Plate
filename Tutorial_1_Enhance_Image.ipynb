# %%
from Utilities.io import DataLoader
from Utilities.painter import Visualizer
from Models.RRDBNet import RRDBNet# we use RRDB in this demo

# %% [markdown]
# ### Load in the sample images

# %%
import glob
DATA_PATH = 'Samples'
loader = DataLoader()
data = loader.load(glob.glob(DATA_PATH + '/*.jpg'), batchSize=1)

painter = Visualizer()
for downSample, original in data.take(3):
    painter.plot(downSample, original)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_487580/3523741672.py in <module>
#       1 import glob
#       2 DATA_PATH = 'Samples'
# ----> 3 loader = DataLoader()
#       4 data = loader.load(glob.glob(DATA_PATH + '/*.jpg'), batchSize=1)
#       5
#
# NameError: name 'DataLoader' is not defined

# %% [markdown]
# ### Load in the pretrained super-resolution model

# %%
# pretrained rrdb network can be found in the Pretrained folder
MODEL_PATH = 'Pretrained/rrdb'
model = RRDBNet(blockNum=10)
model.load_weights(MODEL_PATH)

# %% [markdown]
# ### Run plate enhancement

# %%
for downSample, original in data.take(3):
    
    yPred = model.predict(downSample)
    painter.plot(downSample, original, yPred)
# Out:
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000139A7C83D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
